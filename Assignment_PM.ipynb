# %% [markdown]
# # PREDICTIVE MODELLING ASSIGNMENT 1
# ### REUBEN RAPOSE            J040

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### STEP 1: Reading Pulsar Stars Data set into 'df'

# %%
df= pd.read_csv("D:\College\SEM 6\Assignment\pulsar_stars.csv")

# %%
df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %% [markdown]
# ## STEP 2: Measures of central tendencies

# %% [markdown]
# ## Mean

# %%
a =df.mean() #MEAN
a
# Out:
#  Mean of the integrated profile                  111.079968
#  Standard deviation of the integrated profile     46.549532
#  Excess kurtosis of the integrated profile         0.477857
#  Skewness of the integrated profile                1.770279
#  Mean of the DM-SNR curve                         12.614400
#  Standard deviation of the DM-SNR curve           26.326515
#  Excess kurtosis of the DM-SNR curve               8.303556
#  Skewness of the DM-SNR curve                    104.857709
# target_class                                       0.091574
# dtype: float64

# %% [markdown]
# ## Plotting Mean of all columns

# %%
plt.plot(a)
plt.show()

# %% [markdown]
# ## Median

# %%
c = df.median() #MEDIAN
c
# Out:
#  Mean of the integrated profile                  115.078125
#  Standard deviation of the integrated profile     46.947479
#  Excess kurtosis of the integrated profile         0.223240
#  Skewness of the integrated profile                0.198710
#  Mean of the DM-SNR curve                          2.801839
#  Standard deviation of the DM-SNR curve           18.461316
#  Excess kurtosis of the DM-SNR curve               8.433515
#  Skewness of the DM-SNR curve                     83.064556
# target_class                                       0.000000
# dtype: float64

# %% [markdown]
# ## Plotting Median of all columns

# %%
plt.plot(c)
plt.show()

# %% [markdown]
# ## Mode

# %%
# df.mode()
b = df.fillna(df.mode()) #MODE
b
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# ...

# %% [markdown]
# ## Plotting Mode of all columns

# %%
plt.plot(b)
plt.show()

# %% [markdown]
# ## STEP 3: a) Checking for Null and NA values

# %%
df.isna().sum()
# Out:
#  Mean of the integrated profile                  0
#  Standard deviation of the integrated profile    0
#  Excess kurtosis of the integrated profile       0
#  Skewness of the integrated profile              0
#  Mean of the DM-SNR curve                        0
#  Standard deviation of the DM-SNR curve          0
#  Excess kurtosis of the DM-SNR curve             0
#  Skewness of the DM-SNR curve                    0
# target_class                                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
#  Mean of the integrated profile                  0
#  Standard deviation of the integrated profile    0
#  Excess kurtosis of the integrated profile       0
#  Skewness of the integrated profile              0
#  Mean of the DM-SNR curve                        0
#  Standard deviation of the DM-SNR curve          0
#  Excess kurtosis of the DM-SNR curve             0
#  Skewness of the DM-SNR curve                    0
# target_class                                     0
# dtype: int64

# %% [markdown]
# ## There are no null or NA values in the dataset

# %% [markdown]
# ## STEP 3: b) Checking for outliers

# %%
sns.boxplot(x=df)

# %% [markdown]
# ## Since there are Lots of outliers, we remove them using the z-score

# %%
from scipy import stats

def drop_numerical_outliers(df, z_thresh=3):
    constrains = df.select_dtypes(include=[np.number]) \
        .apply(lambda x: np.abs(stats.zscore(x)) < z_thresh, reduce=False) \
        .all(axis=1)
    # Drop (inplace) values set to be rejected
    df.drop(df.index[~constrains], inplace=True)

# %%
drop_numerical_outliers(df)
# Out:
# C:\Users\REUBEN\Miniconda3\envs\minimal_ds\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The reduce argument is deprecated and will be removed in a future version. You can specify result_type='reduce' to try to reduce the result to the original dimensions
#   """

# %%
df.shape #number of rows have decreased since we removed outliers
# Out:
# (15305, 9)

# %% [markdown]
# ## STEP 4: a) Finding Measures of Central tendancies again after cleaning data

# %%
df.mean() #MEAN
# Out:
#  Mean of the integrated profile                  116.270261
#  Standard deviation of the integrated profile     47.038379
#  Excess kurtosis of the integrated profile         0.215519
#  Skewness of the integrated profile                0.389242
#  Mean of the DM-SNR curve                          4.758669
#  Standard deviation of the DM-SNR curve           21.357588
#  Excess kurtosis of the DM-SNR curve               8.926482
#  Skewness of the DM-SNR curve                    107.939070
# target_class                                       0.000000
# dtype: float64

# %%
df.fillna(df.mode()) #MODE
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17892                        96.000000
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17892                                      44.193113
# 17893                                      59.847421
# ...

# %%
df.median() #MEDIAN
# Out:
#  Mean of the integrated profile                  117.015625
#  Standard deviation of the integrated profile     47.326882
#  Excess kurtosis of the integrated profile         0.191226
#  Skewness of the integrated profile                0.134123
#  Mean of the DM-SNR curve                          2.602843
#  Standard deviation of the DM-SNR curve           17.481970
#  Excess kurtosis of the DM-SNR curve               8.826058
#  Skewness of the DM-SNR curve                     91.995245
# target_class                                       0.000000
# dtype: float64

# %% [markdown]
# ## The mean, median and mode have remained exactly the same indicating that the effect of outliers that we removed was insignificant

# %% [markdown]
# ## STEP 5: Determining the type of variables....Categorical or Continuous variables

# %%
df.dtypes # ALL OUR VARIABLES ARE CONTINUOUS
# Out:
#  Mean of the integrated profile                  float64
#  Standard deviation of the integrated profile    float64
#  Excess kurtosis of the integrated profile       float64
#  Skewness of the integrated profile              float64
#  Mean of the DM-SNR curve                        float64
#  Standard deviation of the DM-SNR curve          float64
#  Excess kurtosis of the DM-SNR curve             float64
#  Skewness of the DM-SNR curve                    float64
# target_class                                       int64
# dtype: object

# %% [markdown]
# ## STEP 6: a) Depicting the relationships between variables using scatter plots and correlation matrix

# %%
sns.pairplot(df) #PLOTTING A SCATTER PLOT BETWEEN TWO VARIABLES AT A TIME
plt.figure(figsize = (16,5))

# %% [markdown]
# ## Correlation Heatmap

# %%
sns.heatmap(df.corr(),annot=True) # CORRELATION MATRIX
